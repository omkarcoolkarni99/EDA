# %% [markdown]
# <h2 align=center>Car Price Exploratory Data Analysis <h2>
# <img src = "https://www.nextbigbrand.in/wp-content/uploads/2019/01/car-dekho-large.png" >

# %% [markdown]
# The input dataset contains information about used cars listed on www.cardekho.com, which I found through a dataset available on Kaggle.

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ### Importing and exploring data

# %%
df_cardekho = pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")

# %%
df_cardekho.info()
df_cardekho.head()
df_cardekho.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# ### Visualise effect of seller type on the selling price

# %%
types_of_seller = df_cardekho.seller_type.unique()
types_of_seller.sort()
print(types_of_seller)
number_of_cars_per_seller_type = df_cardekho.groupby(['seller_type'])['selling_price'].count().tolist()
cars_per_seller_type = df_cardekho.groupby(['seller_type'])['selling_price'].count()
print("Number Of Cars per Seller Type \n" + str(cars_per_seller_type))
selling_price= df_cardekho.groupby(['seller_type'])['selling_price'].mean().tolist()
sp = df_cardekho.groupby(['seller_type'])['selling_price'].mean()
print("Mean Selling Price \n" + str(sp))
plt.figure(figsize=(20,5))
c = ['Blue',"Brown","Green","Grey","Orange"]
ax1 = plt.subplot(1,2,1)
ax1.bar(types_of_seller,number_of_cars_per_seller_type,color = c)
plt.xlabel('types of seller')
plt.ylabel('number of cars per seller type')
ax2 = plt.subplot(1,2,2)
ax2.bar(types_of_seller,selling_price, color = c)
plt.xlabel('types_of_seller')
plt.ylabel('Selling Price')
# Out:
# ['Dealer' 'Individual' 'Trustmark Dealer']
# Number Of Cars per Seller Type
# seller_type
# Dealer               994
# Individual          3244
# Trustmark Dealer     102
# Name: selling_price, dtype: int64
# Mean Selling Price
# seller_type
# Dealer              721822.890342
# Individual          424505.419236
# Trustmark Dealer    914950.980392
# Name: selling_price, dtype: float64
# Text(0, 0.5, 'Selling Price')

# %% [markdown]
# Individual sellers sold more number of cars, however the Trustmark Dealers were able to get best of the selling price
# ***

# %% [markdown]
# ### Visualising the effect of type of owner on the selling price

# %%
types_of_seller = df_cardekho.seller_type.unique()
print(types_of_seller)
types_of_owner = df_cardekho.owner.unique()
print(types_of_owner)
number_of_cars_per_owner_type = df_cardekho.groupby(['owner'])['selling_price'].count().tolist()
cars_per_owner_type = df_cardekho.groupby(['owner'])['selling_price'].count()
print("Number Of Cars per Owner Type \n" + str(cars_per_owner_type))
selling_price= df_cardekho.groupby(['owner'])['selling_price'].mean().tolist()
sp = df_cardekho.groupby(['owner'])['selling_price'].mean()
print("Mean Selling Price \n" + str(sp))
plt.figure(figsize=(20,5))
c = ['Blue',"Brown","Green","Grey","Orange"]
ax1 = plt.subplot(1,2,1)
ax1.bar(types_of_owner,number_of_cars_per_owner_type,color = c)
plt.xlabel('types of owner')
plt.ylabel('number of cars per owner type')
ax2 = plt.subplot(1,2,2)
ax2.bar(types_of_owner,selling_price, color = c)
plt.xlabel('types_of_owner')
plt.ylabel('Selling Price')
# Out:
# ['Individual' 'Dealer' 'Trustmark Dealer']
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']
# Number Of Cars per Owner Type
# owner
# First Owner             2832
# Fourth & Above Owner      81
# Second Owner            1106
# Test Drive Car            17
# Third Owner              304
# Name: selling_price, dtype: int64
# Mean Selling Price
# owner
# First Owner             598636.969633
# Fourth & Above Owner    173901.197531
# Second Owner            343891.088608
# Test Drive Car          954293.941176
# Third Owner             269474.003289
# Name: selling_price, dtype: float64
# Text(0, 0.5, 'Selling Price')

# %% [markdown]
# More number of first owners sold their car, but third owners got the most value for their cars
# ***

# %% [markdown]
# ### Visualising effect of transmission on the selling price

# %%
types_of_transmission = df_cardekho.transmission.unique()
types_of_transmission.sort()
print(types_of_transmission)
number_of_cars_per_owner_type = df_cardekho.groupby(['transmission'])['selling_price'].count().tolist()
cars_per_transmission_type = df_cardekho.groupby(['transmission'])['selling_price'].count()
print("Number Of Cars according to Transmission Type \n" + str(cars_per_transmission_type))
selling_price= df_cardekho.groupby(['transmission'])['selling_price'].mean().tolist()
sp = df_cardekho.groupby(['transmission'])['selling_price'].mean()
print("Mean Selling Price \n" + str(sp))
plt.figure(figsize=(20,5))
c = ['Blue',"Brown","Green","Grey","Orange"]
ax1 = plt.subplot(1,2,1)
ax1.bar(types_of_transmission,cars_per_transmission_type,color = c)
plt.xlabel("Type Of Transmission")
plt.ylabel("Count")
ax2 = plt.subplot(1,2,2)
ax2.bar(types_of_transmission,selling_price, color = c)
plt.ylabel("Selling Price")
plt.xlabel('Type Of Transmission')
# Out:
# ['Automatic' 'Manual']
# Number Of Cars according to Transmission Type
# transmission
# Automatic     448
# Manual       3892
# Name: selling_price, dtype: int64
# Mean Selling Price
# transmission
# Automatic    1.408154e+06
# Manual       4.000667e+05
# Name: selling_price, dtype: float64
# Text(0.5, 0, 'Type Of Transmission')

# %% [markdown]
# More number of Manual cars were sold as compared to that of the automatic cars, but automatic cars were sold at higher price
# *****

# %% [markdown]
# ### Effect of Kms driven on the selling price of the car

# %%
plt.scatter('km_driven','selling_price',data = df_cardekho)
plt.xlabel('Kms Driven')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %% [markdown]
# The cars which are driven less are sold at better price
# ***

# %% [markdown]
# ### Visualising effect of Age on the selling price

# %%
df_cardekho['age'] = 2020- df_cardekho['year']
x = df_cardekho.sort_values(by=['age','selling_price'])
plt.plot('age','selling_price',data = x)
plt.xlabel('Age')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %% [markdown]
# Newer cars sell for higher prices
# ***

# %% [markdown]
# ### Visualising the effect of type of fuel on the selling price of the car

# %%
types_of_fuel = df_cardekho.fuel.unique()
types_of_fuel.sort()
print(types_of_fuel)
number_of_cars_per_fuel_type = df_cardekho.groupby(['fuel'])['selling_price'].count().tolist()
cars_per_fuel_type = df_cardekho.groupby(['fuel'])['selling_price'].count()
print("Number Of Cars according to Fuel Type \n" + str(cars_per_transmission_type))
selling_price= df_cardekho.groupby(['fuel'])['selling_price'].mean().tolist()
sp = df_cardekho.groupby(['fuel'])['selling_price'].mean()
print("Mean Selling Price \n" + str(sp))
plt.figure(figsize=(20,5))
c = ['Blue',"Brown","Green","Grey","Orange"]
ax1 = plt.subplot(1,2,1)
ax1.bar(types_of_fuel,selling_price,color = c)
plt.xlabel("Type Of Fuel")
plt.ylabel("Selling Price")
ax2 = plt.subplot(1,2,2)
ax2.bar(types_of_fuel,cars_per_fuel_type, color =c)
plt.xlabel("Type Of Fuel")
plt.ylabel("Count")
# Out:
# ['CNG' 'Diesel' 'Electric' 'LPG' 'Petrol']
# Number Of Cars according to Fuel Type
# transmission
# Automatic     448
# Manual       3892
# Name: selling_price, dtype: int64
# Mean Selling Price
# fuel
# CNG         277174.925000
# Diesel      669094.252206
# Electric    310000.000000
# LPG         167826.043478
# Petrol      344840.137541
# Name: selling_price, dtype: float64
# Text(0, 0.5, 'Count')

# %% [markdown]
# Diesel cars have most selling price
# ***

# %% [markdown]
# ### Visualising cummulative effect of type of owner,seller type and type of transmission on the selling price

# %%
df_seller_owner = df_cardekho.groupby(by=["seller_type","owner","transmission"])
df_seller_owner.count().sort_values(by="selling_price", ascending=False).plot(kind="bar", y="selling_price")
# Out:
# <AxesSubplot:xlabel='seller_type,owner,transmission'>

# %% [markdown]
# The graph shows that the Individual Sellers who are First Owners of a Manual Car were able to sell the car at maximum price
# ***
